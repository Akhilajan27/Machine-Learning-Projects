# %% [markdown]
# LANDPRICE PREDICTION

# %%
#import libraries
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
#Load Data
df=pd.read_csv(r"C:\Users\user\Downloads\land_prices.csv")
print(df.head())
# Out:
#    property_id         location_name      taluk        village  latitude  \
# 0          1.0              Chevayur  Kozhikode       Chevayur    11.278
# 1          2.0  Medical College Area  Kozhikode      Kozhikode    11.282
# 2          3.0         Kunnamangalam  Kozhikode  Kunnamangalam    11.319
# 3          4.0                Feroke  Kozhikode         Feroke    11.183
# 4          5.0             Balussery  Koyilandy      Balussery    11.445
#
#    longitude  land_area_cents     land_type  distance_to_school_km  \
# 0     75.814              5.5   Residential                    0.8
# 1     75.833              4.0    Commercial                    0.5
# 2     75.879             10.0   Residential                    1.5
# 3     75.833              8.0   Residential                    1.2
# 4     75.828             15.0  Agricultural                    2.5
#
#    distance_to_airport_km  distance_to_railway_station_km  \
# 0                    26.5                             5.1
# 1                    27.1                             6.5
# 2                    25.0                            12.0
# 3                    18.0                             7.5
# 4                    38.0                            18.0
#
#    distance_to_hospital_km  distance_to_medical_college_km  \
# 0                      1.2                             2.5
# 1                      0.3                             0.5
# 2                      3.0                             5.0
# 3                      2.5                            12.0
# 4                      3.5                            20.0
#
#    distance_to_bus_stop_km  distance_to_market_km  price_lakhs
# 0                      0.4                    1.1         16.5
# 1                      0.2                    0.8         22.0
# 2                      0.8                    1.5         25.0
# 3                      0.7                    1.8         20.0
# 4                      1.2                    2.0         18.0

# %%
df['price_per_cent']=df['price_lakhs']/df['land_area_cents']
print(df.head())
# Out:
#    property_id         location_name      taluk        village  latitude  \
# 0          1.0              Chevayur  Kozhikode       Chevayur    11.278
# 1          2.0  Medical College Area  Kozhikode      Kozhikode    11.282
# 2          3.0         Kunnamangalam  Kozhikode  Kunnamangalam    11.319
# 3          4.0                Feroke  Kozhikode         Feroke    11.183
# 4          5.0             Balussery  Koyilandy      Balussery    11.445
#
#    longitude  land_area_cents     land_type  distance_to_school_km  \
# 0     75.814              5.5   Residential                    0.8
# 1     75.833              4.0    Commercial                    0.5
# 2     75.879             10.0   Residential                    1.5
# 3     75.833              8.0   Residential                    1.2
# 4     75.828             15.0  Agricultural                    2.5
#
#    distance_to_airport_km  distance_to_railway_station_km  \
# 0                    26.5                             5.1
# 1                    27.1                             6.5
# 2                    25.0                            12.0
# 3                    18.0                             7.5
# 4                    38.0                            18.0
#
#    distance_to_hospital_km  distance_to_medical_college_km  \
# 0                      1.2                             2.5
# 1                      0.3                             0.5
# 2                      3.0                             5.0
# 3                      2.5                            12.0
# 4                      3.5                            20.0
#
#    distance_to_bus_stop_km  distance_to_market_km  price_lakhs  price_per_cent
# 0                      0.4                    1.1         16.5             3.0
# 1                      0.2                    0.8         22.0             5.5
# 2                      0.8                    1.5         25.0             2.5
# 3                      0.7                    1.8         20.0             2.5
# 4                      1.2                    2.0         18.0             1.2

# %%
print(df.columns)
# Out:
# Index(['property_id', 'location_name', 'taluk', 'village', 'latitude',
#        'longitude', 'land_area_cents', 'land_type', 'distance_to_school_km',
#        'distance_to_airport_km', 'distance_to_railway_station_km',
#        'distance_to_hospital_km', 'distance_to_medical_college_km',
#        'distance_to_bus_stop_km', 'distance_to_market_km', 'price_lakhs',
#        'price_per_cent'],
#       dtype='object')

# %%
numeric_features=['land_area_cents','distance_to_school_km',
       'distance_to_airport_km', 'distance_to_railway_station_km',
       'distance_to_hospital_km', 'distance_to_medical_college_km',
       'distance_to_bus_stop_km', 'distance_to_market_km']
#convert text to numeric
#one - hot encoding
df_processed = pd.get_dummies(df,columns=['location_name','taluk','village','land_type'], drop_first=True)
print(df_processed)
# Out:
#     property_id  latitude  longitude  land_area_cents  distance_to_school_km  \
# 0           1.0    11.278     75.814              5.5                    0.8
# 1           2.0    11.282     75.833              4.0                    0.5
# 2           3.0    11.319     75.879             10.0                    1.5
# 3           4.0    11.183     75.833              8.0                    1.2
# 4           5.0    11.445     75.828             15.0                    2.5
# 5           6.0    11.333     75.750              6.0                    1.0
# 6           7.0    11.196     75.867              7.2                    0.7
# 7           8.0    11.328     75.787             12.0                    2.0
# 8           9.0    11.285     75.795              3.5                    0.4
# 9          10.0    11.411     75.932             20.0                    3.0
# 10         11.0    11.183     75.800              9.0                    1.8
# 11         12.0    11.258     75.952             11.5                    2.2
# 12         13.0    11.433     75.694              5.0                    0.6
# 13         14.0    11.600     75.583              6.5                    1.1
# 14         15.0    11.218     75.827              8.8                    1.5
# 15         16.0    11.222     75.845              4.5                    0.9
# 16         17.0    11.279     75.816              7.0                    0.6
# 17         18.0    11.284     75.835              3.0                    0.3
# 18         19.0    11.321     75.881             12.5                    1.8
# 19         20.0    11.185     75.835              6.5                    1.0
# 20         21.0    11.447     75.830             18.0                    2.8
# 21         22.0    11.335     75.752              7.5                    1.2
# 22         23.0    11.198     75.869              6.0                    0.5
# 23         24.0    11.330     75.789             10.5                    2.5
# 24         25.0    11.287     75.797              4.2                    0.3
# 25         26.0    11.413     75.935             25.0                    2.8
# 26         27.0    11.185     75.802              7.8                    1.6
# 27         28.0    11.260     75.955             14.0                    2.5
# 28         29.0    11.435     75.696              4.0                    0.8
# 29         30.0    11.602     75.585              8.0                    0.9
# 30         31.0    11.220     75.829              9.5                    1.3
# 31         32.0    11.224     75.847              5.8                    1.1
# 32         33.0    11.280     75.818              4.8                    0.5
# 33         34.0    11.283     75.832              5.2                    0.4
# 34         35.0    11.318     75.878              8.5                    1.3
# 35         36.0    11.182     75.832             10.0                    1.5
# 36         37.0    11.444     75.827             13.0                    2.3
# 37         38.0    11.332     75.749              4.5                    0.8
# 38         39.0    11.195     75.866              8.5                    0.6
# 39         40.0    11.327     75.786             14.0                    2.2
# 40         41.0    11.284     75.794              6.0                    0.5
# 41         42.0    11.410     75.931             18.0                    3.2
# 42         43.0    11.184     75.801             10.2                    2.0
# 43         44.0    11.259     75.953              9.0                    2.0
# 44         45.0    11.432     75.693              6.8                    1.0
# 45         46.0    11.601     75.584              7.2                    1.0
# 46         47.0    11.219     75.828              7.0                    1.4
# 47         48.0    11.223     75.846              5.0                    1.0
# 48         49.0    11.268     75.889             15.0                    2.5
# 49         50.0    11.340     75.908              8.0                    1.2
#
#     distance_to_airport_km  distance_to_railway_station_km  \
# 0                     26.5                             5.1
# 1                     27.1                             6.5
# 2                     25.0                            12.0
# 3                     18.0                             7.5
# 4                     38.0                            18.0
# 5                     35.0                            10.0
# 6                     15.0                            12.0
# 7                     30.0                             8.0
# 8                     28.0                             3.0
# 9                     40.0                            30.0
# 10                    22.0                             9.0
# 11                    20.0                            18.0
# 12                    45.0                             1.5
# 13                    55.0                             2.0
# 14                    20.0                             6.0
# 15                    22.0                             8.0
# 16                    26.8                             5.5
# 17                    27.5                             6.8
# 18                    25.5                            12.5
# 19                    17.5                             7.0
# 20                    38.5                            18.5
# 21                    35.5                            10.5
# 22                    14.5                            11.5
# 23                    30.5                             8.5
# 24                    28.2                             3.2
# 25                    40.5                            30.5
# 26                    21.5                             8.5
# 27                    19.5                            18.5
# 28                    45.5                             1.8
# 29                    54.5                             1.8
# 30                    19.5                             5.5
# 31                    22.5                             8.5
# 32                    27.0                             5.8
# 33                    27.2                             6.6
# 34                    24.8                            11.8
# 35                    18.5                             8.0
# 36                    37.8                            17.8
# 37                    34.8                             9.8
# 38                    15.2                            12.2
# 39                    30.2                             8.2
# 40                    28.1                             3.1
# 41                    40.2                            30.2
# 42                    22.2                             9.2
# 43                    19.8                            18.2
# 44                    45.2                             1.3
# 45                    55.2                             2.2
# 46                    19.8                             5.8
# 47                    22.2                             8.2
# 48                    23.0                            15.0
# 49                    30.0                            20.0
#
#     distance_to_hospital_km  distance_to_medical_college_km  \
# 0                       1.2                             2.5
# 1                       0.3                             0.5
# 2                       3.0                             5.0
# 3                       2.5                            12.0
# 4                       3.5                            20.0
# 5                       4.0                            15.0
# 6                       1.8                            10.0
# 7                       2.8                             7.0
# 8                       1.0                             4.5
# 9                       2.5                            22.0
# 10                      3.0                            14.0
# 11                      1.5                            10.0
# 12                      0.8                            25.0
# 13                      1.2                            40.0
# 14                      2.1                            11.0
# 15                      1.5                             9.0
# 16                      1.0                             2.2
# 17                      0.5                             0.8
# 18                      3.2                             5.5
# 19                      2.0                            11.5
# 20                      3.8                            20.5
# 21                      4.2                            15.5
# 22                      1.5                             9.5
# 23                      3.0                             7.5
# 24                      0.8                             4.2
# 25                      2.2                            22.5
# 26                      2.8                            13.5
# 27                      1.8                            10.5
# 28                      1.0                            25.5
# 29                      1.0                            39.5
# 30                      1.9                            10.5
# 31                      1.8                             9.5
# 32                      0.9                             2.0
# 33                      0.4                             0.6
# 34                      2.8                             4.8
# 35                      2.8                            12.5
# 36                      3.3                            19.8
# 37                      3.8                            14.8
# 38                      1.6                            10.2
# 39                      2.6                             7.2
# 40                      1.1                             4.6
# 41                      2.6                            22.2
# 42                      3.2                            14.2
# 43                      1.3                            10.3
# 44                      0.9                            25.2
# 45                      1.4                            40.2
# 46                      2.0                            10.8
# 47                      1.6                             9.2
# 48                      4.0                             7.0
# 49                      1.5                            12.0
#
#     distance_to_bus_stop_km  ...  village_Kunnamangalam  village_Mavoor  \
# 0                       0.4  ...                  False           False
# 1                       0.2  ...                  False           False
# 2                       0.8  ...                   True           False
# 3                       0.7  ...                  False           False
# 4                       1.2  ...                  False           False
# 5                       0.5  ...                  False           False
# 6                       0.3  ...                  False           False
# 7                       1.0  ...                  False           False
# 8                       0.2  ...                  False           False
# 9                       1.5  ...                  False           False
# 10                      0.9  ...                  False           False
# 11                      1.1  ...                  False            True
# 12                      0.4  ...                  False           False
# 13                      0.6  ...                  False           False
# 14                      0.8  ...                  False           False
# 15                      0.3  ...                  False           False
# 16                      0.3  ...                  False           False
# 17                      0.1  ...                  False           False
# 18                      1.0  ...                   True           False
# 19                      0.5  ...                  False           False
# 20                      1.5  ...                  False           False
# 21                      0.6  ...                  False           False
# 22                      0.2  ...                  False           False
# 23                      1.2  ...                  False           False
# 24                      0.1  ...                  False           False
# 25                      1.3  ...                  False           False
# 26                      0.7  ...                  False           False
# 27                      1.3  ...                  False            True
# 28                      0.5  ...                  False           False
# 29                      0.4  ...                  False           False
# 30                      0.7  ...                  False           False
# 31                      0.5  ...                  False           False
# 32                      0.2  ...                  False           False
# 33                      0.2  ...                  False           False
# 34                      0.6  ...                   True           False
# 35                      1.0  ...                  False           False
# 36                      1.0  ...                  False           False
# 37                      0.4  ...                  False           False
# 38                      0.4  ...                  False           False
# 39                      1.1  ...                  False           False
# 40                      0.3  ...                  False           False
# 41                      1.6  ...                  False           False
# 42                      1.1  ...                  False           False
# 43                      1.0  ...                  False            True
# 44                      0.6  ...                  False           False
# 45                      0.8  ...                  False           False
# 46                      0.6  ...                  False           False
# 47                      0.4  ...                  False           False
# 48                      1.5  ...                  False           False
# 49                      0.5  ...                  False           False
#
#     village_Olavanna  village_Pantheerankavu  village_Peruvayal  \
# 0              False                   False              False
# 1              False                   False              False
# 2              False                   False              False
# 3              False                   False              False
# 4              False                   False              False
# 5              False                   False              False
# 6              False                   False              False
# 7              False                   False              False
# 8              False                   False              False
# 9              False                   False              False
# 10             False                   False              False
# 11             False                   False              False
# 12             False                   False              False
# 13             False                   False              False
# 14              True                   False              False
# 15             False                    True              False
# 16             False                   False              False
# 17             False                   False              False
# 18             False                   False              False
# 19             False                   False              False
# 20             False                   False              False
# 21             False                   False              False
# 22             False                   False              False
# 23             False                   False              False
# 24             False                   False              False
# 25             False                   False              False
# 26             False                   False              False
# 27             False                   False              False
# 28             False                   False              False
# 29             False                   False              False
# 30              True                   False              False
# 31             False                    True              False
# 32             False                   False              False
# 33             False                   False              False
# 34             False                   False              False
# 35             False                   False              False
# 36             False                   False              False
# 37             False                   False              False
# 38             False                   False              False
# 39             False                   False              False
# 40             False                   False              False
# 41             False                   False              False
# 42             False                   False              False
# 43             False                   False              False
# 44             False                   False              False
# 45             False                   False              False
# 46              True                   False              False
# 47             False                    True              False
# 48             False                   False               True
# 49             False                   False              False
#
#     village_Ramanattukara  village_Thamarassery  village_Vatakara  \
# 0                   False                 False             False
# 1                   False                 False             False
# 2                   False                 False             False
# 3                   False                 False             False
# 4                   False                 False             False
# 5                   False                 False             False
# 6                    True                 False             False
# 7                   False                 False             False
# 8                   False                 False             False
# 9                   False                  True             False
# 10                  False                 False             False
# 11                  False                 False             False
# 12                  False                 False             False
# 13                  False                 False              True
# 14                  False                 False             False
# 15                  False                 False             False
# 16                  False                 False             False
# 17                  False                 False             False
# 18                  False                 False             False
# 19                  False                 False             False
# 20                  False                 False             False
# 21                  False                 False             False
# 22                   True                 False             False
# 23                  False                 False             False
# 24                  False                 False             False
# 25                  False                  True             False
# 26                  False                 False             False
# 27                  False                 False             False
# 28                  False                 False             False
# 29                  False                 False              True
# 30                  False                 False             False
# 31                  False                 False             False
# 32                  False                 False             False
# 33                  False                 False             False
# 34                  False                 False             False
# 35                  False                 False             False
# 36                  False                 False             False
# 37                  False                 False             False
# 38                   True                 False             False
# 39                  False                 False             False
# 40                  False                 False             False
# 41                  False                  True             False
# 42                  False                 False             False
# 43                  False                 False             False
# 44                  False                 False             False
# 45                  False                 False              True
# 46                  False                 False             False
# 47                  False                 False             False
# 48                  False                 False             False
# 49                  False                 False             False
#
#     land_type_Commercial  land_type_Residential
# 0                  False                   True
# 1                   True                  False
# 2                  False                   True
# 3                  False                   True
# 4                  False                  False
# 5                  False                   True
# 6                   True                  False
# 7                  False                   True
# 8                  False                   True
# 9                  False                  False
# 10                 False                   True
# 11                 False                   True
# 12                  True                  False
# 13                 False                   True
# 14                 False                   True
# 15                  True                  False
# 16                 False                   True
# 17                 False                   True
# 18                 False                  False
# 19                  True                  False
# 20                 False                   True
# 21                 False                   True
# 22                 False                   True
# 23                 False                  False
# 24                  True                  False
# 25                 False                   True
# 26                 False                   True
# 27                 False                  False
# 28                 False                   True
# 29                  True                  False
# 30                 False                   True
# 31                 False                   True
# 32                  True                  False
# 33                 False                   True
# 34                  True                  False
# 35                 False                  False
# 36                 False                   True
# 37                  True                  False
# 38                 False                   True
# 39                 False                   True
# 40                 False                   True
# 41                 False                   True
# 42                 False                  False
# 43                 False                   True
# 44                 False                   True
# 45                 False                   True
# 46                  True                  False
# 47                 False                   True
# 48                 False                  False
# 49                  True                  False
#
# [50 rows x 52 columns]

# %%
dummy_features=[]
for column_name in df_processed.columns:
    if column_name.startswith('land_type') or column_name.startswith('village') or column_name.startswith('location_name') or column_name.startswith('taluk'):
      dummy_features.append(column_name)  
print(dummy_features)
# Out:
# ['location_name_Beypore', 'location_name_Chevayur', 'location_name_Elathur', 'location_name_Feroke', 'location_name_Kakkodi', 'location_name_Karaparamba', 'location_name_Koduvally', 'location_name_Koyilandy', 'location_name_Kunnamangalam', 'location_name_Mavoor', 'location_name_Medical College Area', 'location_name_Olavanna', 'location_name_Pantheerankavu', 'location_name_Peruvayal', 'location_name_Ramanattukara', 'location_name_Thamarassery', 'location_name_Vatakara', 'taluk_Kozhikode', 'taluk_Thamarassery', 'taluk_Vatakara', 'village_Beypore', 'village_Chevayur', 'village_Elathur', 'village_Feroke', 'village_Kakkodi', 'village_Karaparamba', 'village_Koduvally', 'village_Koyilandy', 'village_Kozhikode', 'village_Kunnamangalam', 'village_Mavoor', 'village_Olavanna', 'village_Pantheerankavu', 'village_Peruvayal', 'village_Ramanattukara', 'village_Thamarassery', 'village_Vatakara', 'land_type_Commercial', 'land_type_Residential']

# %%
features=numeric_features+dummy_features
print(features)
# Out:
# ['land_area_cents', 'distance_to_school_km', 'distance_to_airport_km', 'distance_to_railway_station_km', 'distance_to_hospital_km', 'distance_to_medical_college_km', 'distance_to_bus_stop_km', 'distance_to_market_km', 'location_name_Beypore', 'location_name_Chevayur', 'location_name_Elathur', 'location_name_Feroke', 'location_name_Kakkodi', 'location_name_Karaparamba', 'location_name_Koduvally', 'location_name_Koyilandy', 'location_name_Kunnamangalam', 'location_name_Mavoor', 'location_name_Medical College Area', 'location_name_Olavanna', 'location_name_Pantheerankavu', 'location_name_Peruvayal', 'location_name_Ramanattukara', 'location_name_Thamarassery', 'location_name_Vatakara', 'taluk_Kozhikode', 'taluk_Thamarassery', 'taluk_Vatakara', 'village_Beypore', 'village_Chevayur', 'village_Elathur', 'village_Feroke', 'village_Kakkodi', 'village_Karaparamba', 'village_Koduvally', 'village_Koyilandy', 'village_Kozhikode', 'village_Kunnamangalam', 'village_Mavoor', 'village_Olavanna', 'village_Pantheerankavu', 'village_Peruvayal', 'village_Ramanattukara', 'village_Thamarassery', 'village_Vatakara', 'land_type_Commercial', 'land_type_Residential']

# %%
#x = Features
#y= Price_per_cent
x=df_processed[features]
y=df_processed['price_per_cent']

# %%
#split data to train and test by 80/20
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#choose model
from sklearn.ensemble import RandomForestRegressor
#create model
model=RandomForestRegressor(n_estimators=100, random_state=42)
#train model
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
#Evaluation
y_pred=model.predict(X_test)
df_comparison=pd.DataFrame({'Actual:':y_test,'Predicted:':y_pred})
print(df_comparison.head())
# Out:
#     Actual:  Predicted:
# 13      2.2       2.535
# 39      1.7       1.602
# 30      2.1       2.427
# 45      2.1       2.474
# 17      5.0       4.455

# %%
#try new land record
features_list=model.feature_names_in_.tolist()
print(features_list)
# Out:
# ['land_area_cents', 'distance_to_school_km', 'distance_to_airport_km', 'distance_to_railway_station_km', 'distance_to_hospital_km', 'distance_to_medical_college_km', 'distance_to_bus_stop_km', 'distance_to_market_km', 'location_name_Beypore', 'location_name_Chevayur', 'location_name_Elathur', 'location_name_Feroke', 'location_name_Kakkodi', 'location_name_Karaparamba', 'location_name_Koduvally', 'location_name_Koyilandy', 'location_name_Kunnamangalam', 'location_name_Mavoor', 'location_name_Medical College Area', 'location_name_Olavanna', 'location_name_Pantheerankavu', 'location_name_Peruvayal', 'location_name_Ramanattukara', 'location_name_Thamarassery', 'location_name_Vatakara', 'taluk_Kozhikode', 'taluk_Thamarassery', 'taluk_Vatakara', 'village_Beypore', 'village_Chevayur', 'village_Elathur', 'village_Feroke', 'village_Kakkodi', 'village_Karaparamba', 'village_Koduvally', 'village_Koyilandy', 'village_Kozhikode', 'village_Kunnamangalam', 'village_Mavoor', 'village_Olavanna', 'village_Pantheerankavu', 'village_Peruvayal', 'village_Ramanattukara', 'village_Thamarassery', 'village_Vatakara', 'land_type_Commercial', 'land_type_Residential']

# %%
new_land_property = [{
    'land_area_cents': 5.5,
    'distance_to_school_km': 0.8,
    'distance_to_airport_km': 26.5,
    'distance_to_railway_station_km': 5.1,
    'distance_to_hospital_km': 1.2,
    'distance_to_medical_college_km': 2.5,
    'distance_to_bus_stop_km': 0.4,
    'distance_to_market_km': 1.1, 
    'location_name_Beypore': 0,
    'location_name_Chevayur': 1,
    'location_name_Elathur': 0,
    'location_name_Feroke': 0,
    'location_name_Kakkodi': 0,
    'location_name_Karaparamba': 0,
    'location_name_Koduvally': 0,
    'location_name_Koyilandy': 0,
    'location_name_Kunnamangalam': 0,
    'location_name_Mavoor': 0,
    'location_name_Medical College Area': 0,
    'location_name_Olavanna': 0,
    'location_name_Pantheerankavu': 0,
    'location_name_Peruvayal': 0,
    'location_name_Ramanattukara': 0,
    'location_name_Thamarassery': 0,
    'location_name_Vatakara': 0,
    'taluk_Kozhikode': 1,
    'taluk_Thamarassery': 0,
    'taluk_Vatakara': 0,
    'village_Beypore': 0,
    'village_Chevayur': 1,
    'village_Elathur': 0,
    'village_Feroke': 0,
    'village_Kakkodi': 0,
    'village_Karaparamba': 0,
    'village_Koduvally': 0,
    'village_Koyilandy': 0,
    'village_Kozhikode': 0,
    'village_Kunnamangalam': 0,
    'village_Mavoor': 0,
    'village_Olavanna': 0,
    'village_Pantheerankavu': 0,
    'village_Peruvayal': 0,
    'village_Ramanattukara': 0,
    'village_Thamarassery': 0,
    'village_Vatakara': 0,
    'land_type_Commercial': 0,
    'land_type_Residential': 1
}]
new_land_df = pd.DataFrame(new_land_property)

new_land_predicted_value = model.predict(new_land_df)
print(new_land_predicted_value)
# Out:
# [3.226]
